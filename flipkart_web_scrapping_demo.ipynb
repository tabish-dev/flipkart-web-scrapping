# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
import pandas as pd

# %%
URL = "https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=TRENDING&suggestionId=mobiles&requestId=a7d40707-4204-4596-a6c4-e02fe229947f"

# %%
#A User Agent string contains information about the browser's identity.
#The User Agent String is reported to the web server as an HTTP header every time that a browser makes a request to a web server.

Headers = ({'User-Agent':'',    # Wite your User Agent String here
          'Accept-Language':'en-US, en;q=0.5 '})

# %%
webpage = requests.get(URL, headers=Headers)

# %%
webpage
# Out:
# <Response [200]>

# %%
# For now the retrieved data is in bytes format

type(webpage.content)
# Out:
# bytes

# %%
# We use BeautifulSoup to parse it into html format

soup = BeautifulSoup(webpage.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links = soup.find_all('a', attrs={'class':'_1fQZEK'})

# %%
links
# Out:
# [<a class="_1fQZEK" href="/poco-x5-pro-5g-horizon-blue-128-gb/p/itm4cef23ac6a3f8?pid=MOBGMDKQBTFQUYDX&amp;lid=LSTMOBGMDKQBTFQUYDX6TMHT4&amp;marketplace=FLIPKART&amp;q=mobiles&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&amp;otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&amp;fm=organic&amp;iid=en_Bjq0EL9lvDunPPbqMSVTbvhNfjphX9SlbylnSPfdrH9NkjCzqVWOWdaD9mFD3-zddZEYj7GH3KjoyX23U7t5GQ%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=98tci0zank0000001699956645308&amp;qH=eb4af0bf07c16429" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="POCO X5 Pro 5G (Horizon Blue, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/n/v/2/-original-imagmkjfjwtzhaag.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly=""
# ...

# %%
link1= links[0].get('href')

# %%
link1
# Out:
# '/poco-x5-pro-5g-horizon-blue-128-gb/p/itm4cef23ac6a3f8?pid=MOBGMDKQBTFQUYDX&lid=LSTMOBGMDKQBTFQUYDX6TMHT4&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_1&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&fm=organic&iid=en_Bjq0EL9lvDunPPbqMSVTbvhNfjphX9SlbylnSPfdrH9NkjCzqVWOWdaD9mFD3-zddZEYj7GH3KjoyX23U7t5GQ%3D%3D&ppt=None&ppn=None&ssid=98tci0zank0000001699956645308&qH=eb4af0bf07c16429'

# %%
product1_link = 'https://www.flipkart.com' + link1

# %%
product1_link
# Out:
# 'https://www.flipkart.com/poco-x5-pro-5g-horizon-blue-128-gb/p/itm4cef23ac6a3f8?pid=MOBGMDKQBTFQUYDX&lid=LSTMOBGMDKQBTFQUYDX6TMHT4&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_1&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&fm=organic&iid=en_Bjq0EL9lvDunPPbqMSVTbvhNfjphX9SlbylnSPfdrH9NkjCzqVWOWdaD9mFD3-zddZEYj7GH3KjoyX23U7t5GQ%3D%3D&ppt=None&ppn=None&ssid=98tci0zank0000001699956645308&qH=eb4af0bf07c16429'

# %%
first_item_request = requests.get(product1_link, headers=Headers)

# %%
first_item_request
# Out:
# <Response [200]>

# %%
type(first_item_request.content)
# Out:
# bytes

# %%
first_item_parsed = BeautifulSoup(second_item.content, 'html.parser')

# %%
first_item_parsed
# Out:
# <!DOCTYPE html>
# ...

# %%
first_item_title = first_item_parsed.find('span', attrs={'class':'B_NuCI'}).text.strip()

# %%
first_item_title
# Out:
# 'POCO X5 Pro 5G (Horizon Blue, 128 GB)\xa0\xa0(6 GB RAM)'

# %%
first_item_price = first_item_parsed.find('div', attrs={'class':'_30jeq3 _16Jk6d'}).text

# %%
first_item_price
# Out:
# '₹18,499'

# %%
first_item_rating = first_item_parsed.find('div', attrs={'class':'_3LWZlK'}).text

# %%
first_item_rating
# Out:
# '4.3'

# %%
first_item_review_count = first_item_parsed.find('span', attrs={'class':'_2_R_DZ'}).text.strip()

# %%
first_item_review_count
# Out:
# '20,527 Ratings\xa0&\xa02,136 Reviews'
